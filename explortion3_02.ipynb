# %% [markdown]
# <a href="https://colab.research.google.com/github/gong-aipel/AIFFEL_quest-cr/blob/main/explortion3_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 📌 Colab에서 필요한 라이브러리 설치
# !pip install -q torch torchvision
# !pip install -q matplotlib

# 📁 Google Drive에서 이미지 업로드
from google.colab import files
uploaded = files.upload()

from PIL import Image
import numpy as np
import cv2
import torch
import torchvision.models.segmentation as models
from torchvision import transforms
import matplotlib.pyplot as plt

# 🔍 업로드한 이미지 열기
uploaded_filename = list(uploaded.keys())[0]
original_img = Image.open(uploaded_filename).convert("RGB")
original_img_resized = original_img.resize((512, 512))
original_cv = cv2.cvtColor(np.array(original_img_resized), cv2.COLOR_RGB2BGR)

# 🧠 DeepLab 모델 로딩 (COCO pretrained)
model = models.deeplabv3_resnet101(pretrained=True).eval()

# 🔧 이미지 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
input_tensor = transform(original_img_resized).unsqueeze(0)

# 🔍 마스크 예측
with torch.no_grad():
    output = model(input_tensor)['out'][0]
mask = output.argmax(0).byte().cpu().numpy()

# 👤 사람(class 15) 마스크
person_mask = (mask == 15).astype(np.uint8)
mask_3ch = np.stack([person_mask]*3, axis=2)

# 🎯 (1) 인물모드: 배경 아웃포커싱
blurred_bg = cv2.GaussianBlur(original_cv, (25, 25), 0)
focused_img = np.where(mask_3ch == 1, original_cv, blurred_bg)

# 🎯 (2) 배경 합성 (크로마키)
sky_background = np.full_like(original_cv, (255, 220, 200))  # 연한 하늘색
chroma_key_img = np.where(mask_3ch == 1, original_cv, sky_background)

# 🎯 (3) 문제 영역 시각화 예시
highlight_img = original_cv.copy()
highlight_img[person_mask == 0] = (highlight_img[person_mask == 0] * 0.5).astype(np.uint8)
cv2.circle(highlight_img, (130, 100), 20, (0, 0, 255), 2)  # 모서리 오분류
cv2.circle(highlight_img, (300, 400), 20, (255, 0, 0), 2)  # 머리 경계 흐림

# 🖼️ 이미지 시각화
def show(title, img_bgr):
    plt.figure(figsize=(6,6))
    plt.title(title)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
    plt.show()

show("원본 이미지", original_cv)
show("1️⃣ 인물모드 (아웃포커싱)", focused_img)
show("2️⃣ 크로마키 배경 합성", chroma_key_img)
show("3️⃣ 시맨틱 세그멘테이션 문제 영역", highlight_img)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 90.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 72.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 82.7 MB/s eta 0:00:00
#      <input type="file" id="files-aad3a30d-8300-4d78-9d74-098e1fd5280b" name="files[]" multiple disabled
#         style="border:none" />
# ...

# %%
# 📌 Colab에서 필요한 라이브러리 설치
# !pip install -q torch torchvision
# !pip install -q matplotlib

# 📁 Google Drive에서 이미지 업로드
from google.colab import files
uploaded = files.upload()

from PIL import Image
import numpy as np
import cv2
import torch
import torchvision.models.segmentation as models
from torchvision import transforms
import matplotlib.pyplot as plt

# 🔍 업로드한 이미지 열기
uploaded_filename = list(uploaded.keys())[0]
original_img = Image.open(uploaded_filename).convert("RGB")
original_img_resized = original_img.resize((512, 512))
original_cv = cv2.cvtColor(np.array(original_img_resized), cv2.COLOR_RGB2BGR)

# 🧠 DeepLab 모델 로딩 (COCO pretrained)
model = models.deeplabv3_resnet101(pretrained=True).eval()

# 🔧 이미지 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
input_tensor = transform(original_img_resized).unsqueeze(0)

# 🔍 마스크 예측
with torch.no_grad():
    output = model(input_tensor)['out'][0]
mask = output.argmax(0).byte().cpu().numpy()

# 👤 사람(class 15) 마스크
person_mask = (mask == 15).astype(np.uint8)
mask_3ch = np.stack([person_mask]*3, axis=2)

# 🎯 (1) 인물모드: 배경 아웃포커싱
blurred_bg = cv2.GaussianBlur(original_cv, (25, 25), 0)
focused_img = np.where(mask_3ch == 1, original_cv, blurred_bg)

# 🎯 (2) 배경 합성 (크로마키)
sky_background = np.full_like(original_cv, (255, 220, 200))  # 연한 하늘색
chroma_key_img = np.where(mask_3ch == 1, original_cv, sky_background)

# 🎯 (3) 문제 영역 시각화 예시
highlight_img = original_cv.copy()
highlight_img[person_mask == 0] = (highlight_img[person_mask == 0] * 0.5).astype(np.uint8)
cv2.circle(highlight_img, (130, 100), 20, (0, 0, 255), 2)  # 모서리 오분류
cv2.circle(highlight_img, (300, 400), 20, (255, 0, 0), 2)  # 머리 경계 흐림

# 🖼️ 이미지 시각화
def show(title, img_bgr):
    plt.figure(figsize=(6,6))
    plt.title(title)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
    plt.show()

show("원본 이미지", original_cv)
show("1️⃣ 인물모드 (아웃포커싱)", focused_img)
show("2️⃣ 크로마키 배경 합성", chroma_key_img)
show("3️⃣ 시맨틱 세그멘테이션 문제 영역", highlight_img)
# Out:
#      <input type="file" id="files-6526ea96-00d6-4984-9f91-43b159321c2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6526ea96-00d6-4984-9f91-43b159321c2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 📌 Colab에서 필요한 라이브러리 설치
# !pip install -q torch torchvision
# !pip install -q matplotlib

# 📁 Google Drive에서 이미지 업로드
from google.colab import files
uploaded = files.upload()

from PIL import Image
import numpy as np
import cv2
import torch
import torchvision.models.segmentation as models
from torchvision import transforms
import matplotlib.pyplot as plt

# 🔍 업로드한 이미지 열기
uploaded_filename = list(uploaded.keys())[0]
original_img = Image.open(uploaded_filename).convert("RGB")
original_img_resized = original_img.resize((512, 512))
original_cv = cv2.cvtColor(np.array(original_img_resized), cv2.COLOR_RGB2BGR)

# 🧠 DeepLab 모델 로딩 (COCO pretrained)
model = models.deeplabv3_resnet101(pretrained=True).eval()

# 🔧 이미지 전처리
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])
input_tensor = transform(original_img_resized).unsqueeze(0)

# 🔍 마스크 예측
with torch.no_grad():
    output = model(input_tensor)['out'][0]
mask = output.argmax(0).byte().cpu().numpy()

# 👤 사람(class 15) 마스크
person_mask = (mask == 15).astype(np.uint8)
mask_3ch = np.stack([person_mask]*3, axis=2)

# 🎯 (1) 인물모드: 배경 아웃포커싱
blurred_bg = cv2.GaussianBlur(original_cv, (25, 25), 0)
focused_img = np.where(mask_3ch == 1, original_cv, blurred_bg)

# 🎯 (2) 배경 합성 (크로마키)
sky_background = np.full_like(original_cv, (255, 220, 200))  # 연한 하늘색
chroma_key_img = np.where(mask_3ch == 1, original_cv, sky_background)

# 🎯 (3) 문제 영역 시각화 예시
highlight_img = original_cv.copy()
highlight_img[person_mask == 0] = (highlight_img[person_mask == 0] * 0.5).astype(np.uint8)
cv2.circle(highlight_img, (130, 100), 20, (0, 0, 255), 2)  # 모서리 오분류
cv2.circle(highlight_img, (300, 400), 20, (255, 0, 0), 2)  # 머리 경계 흐림

# 🖼️ 이미지 시각화
def show(title, img_bgr):
    plt.figure(figsize=(6,6))
    plt.title(title)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
    plt.show()

show("원본 이미지", original_cv)
show("1️⃣ 인물모드 (아웃포커싱)", focused_img)
show("2️⃣ 크로마키 배경 합성", chroma_key_img)
show("3️⃣ 시맨틱 세그멘테이션 문제 영역", highlight_img)
# Out:
#      <input type="file" id="files-34750692-00ef-4830-a99c-fae2aefbad55" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34750692-00ef-4830-a99c-fae2aefbad55">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
